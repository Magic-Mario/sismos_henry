# %% [markdown]
# # EDA

# %% [markdown]
# El objetivo de este análisis exploratorio de datos (EDA) es examinar un conjunto de datos relacionados a terremotos procedentes de tres fuentes de datos diferentes: Estados Unidos, Chile y Japón. Nuestro objetivo principal es determinar qué columnas son las más adecuadas para construir un modelo de clasificación de terremotos, pero también buscamos identificar columnas compatibles en las tres fuentes para generar una única fuente de datos consolidada. Se comenzará con el dataframe de Estados Unidos por ser el más grande y con base en este, se iniciará la búsqueda de las columnas compatibles de las otras 2 fuente de datos.

# %% [markdown]
# El conjunto de datos recopila información sobre terremotos registrados en cada uno de estos países, incluyendo datos como magnitud, profundidad, ubicación geográfica, entre otros atributos relevantes. La diversidad de las fuentes nos brinda la oportunidad de examinar diferentes perspectivas y enfoques en el estudio de los terremotos.

# %% [markdown]
# Nuestro primer objetivo es llevar a cabo el análisis exploratorio de datos en cada una de las fuentes por separado. Esto implica clasificar las columnas según su tipo de datos y realizar un análisis más detallado para comprender su distribución. Este enfoque nos permitirá entender mejor las características y patrones específicos presentes en los terremotos registrados en cada país.

# %% [markdown]
# Una vez completado el análisis individual de las fuentes de datos, nuestro segundo objetivo es buscar columnas que sean compatibles en las tres fuentes. Esto implica identificar variables comunes y consistentes entre los conjuntos de datos de Estados Unidos, Chile y Japón. Al encontrar estas columnas compartidas, podremos generar una única fuente de datos consolidada, lo cual facilitará la construcción de un modelo de clasificación robusto y generalizable.

# %% [markdown]
# ## Librerías a usar:

# %%
#!pip install wordcloud

import IPython
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')
import re

IPython.display.clear_output()

# %% [markdown]
# ## USA

# %% [markdown]
# ### Creación del dataframe a analizar:

# %%
df = pd.read_csv('../../src/data/usa_df.csv')

# %% [markdown]
# ### Comienzo del analisis:

# %% [markdown]
# Se comenzará el analisis del dataframe de USA, observando los metadatos del mismo, para proseguir con una analisis más especifico sobre sus columnas.

# %%
df.shape
# Out:
# (429325, 22)

# %% [markdown]
# El dataframe contiene 22 columnas y 429325 filas.

# %%
df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %% [markdown]
# El nombre de las columnas son:
#
# - time
# - latitude
# - longitude
# - depth
# - mag
# - magType
# - ns
# - gap
# - dmin
# - rms
# - net
# - id
# - updated
# - place
# - typ
# - horizontalError
# - depthError
# - magError
# - magNst
# - status
# - locationSource
# - magSource

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429325 entries, 0 to 429324
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             429325 non-null  object
#  1   latitude         429325 non-null  float64
#  2   longitude        429325 non-null  float64
#  3   depth            429325 non-null  float64
#  4   mag              429325 non-null  float64
#  5   magType          429324 non-null  object
#  6   nst              423185 non-null  float64
#  7   gap              429289 non-null  float64
#  8   dmin             425008 non-null  float64
#  9   rms              429232 non-null  float64
#  10  net              429325 non-null  object
#  11  id               429325 non-null  object
#  12  updated          429325 non-null  object
#  13  place            428485 non-null  object
#  14  type             429325 non-null  object
#  15  horizontalError  349461 non-null  float64
#  16  depthError       429233 non-null  float64
#  17  magError         392201 non-null  float64
#  18  magNst           410596 non-null  float64
#  19  status           429325 non-null  object
#  20  locationSource   429325 non-null  object
#  21  magSource        429325 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 72.1+ MB

# %% [markdown]
# Las columnas del dataframe tienen distintos tipos de datos, por lo que se pueden categorizar las columnas por el tipo de datos que contengan.
#
# Columnas tipo object( columnas que muy probablemente tengan datos del tipo string o de texto ):
#
# - time
# - magType
# - net
# - id
# - updated
# - place
# - type
# - status
# - locationSource
# - magSource
#
# Columnas tipo float( columnas con datos numericos decimales ):
#
# - latitude
# - longitude
# - depth
# - mag
# - nst
# - gap
# - dmin
# - rms
# - horizontalError
# - depthError
# - magError
# - magNst
#
# Se analizará primero las columnas con datos de tipo string(texto), para continuar posteriormente con las de tipo numerico.

# %% [markdown]
# ### Columnas de tipo texto

# %% [markdown]
# Antes de empezar el analisis de cada columna, es necesario entender a qué hace referencia cada columna, y nombrarlas con nombres más faciles de entender. Observemos de forma general el contenido del dataframe en busca de darle un mejor nombre a las columnas por su contenido.

# %%
df.select_dtypes(include=['object']).head()
# Out:
#                        time magType net          id                   updated
# 0  2023-06-29T04:46:02.350Z      md  nc  nc73906566  2023-06-29T05:02:15.178Z  \
# 1  2023-06-29T04:45:40.370Z      ml  ci  ci40498704  2023-06-29T04:49:10.599Z
# 2  2023-06-29T04:23:14.270Z      md  nc  nc73906556  2023-06-29T04:39:17.028Z
# 3  2023-06-29T03:57:40.330Z      ml  ci  ci40498656  2023-06-29T04:08:55.110Z
# 4  2023-06-29T03:26:25.154Z      ml  ok  ok2023mphw  2023-06-29T03:29:05.456Z
#
#                                place        type     status locationSource
# 0          3km NW of The Geysers, CA  earthquake  automatic             nc  \
# 1             9km S of Idyllwild, CA  earthquake  automatic             ci
# 2          7km NW of The Geysers, CA  earthquake  automatic             nc
# 3            2km ESE of Redlands, CA  earthquake  automatic             ci
# 4  10 km WNW of Kingfisher, Oklahoma  earthquake  automatic             ok
#
#   magSource
# 0        nc
# 1        ci
# 2        nc
# 3        ci
# 4        ok

# %% [markdown]
# - La columna time, hace referencia a la fecha con su respectiva hora en la que se tomó la medida del evento, se cambiará su nombre a "fecha". Como esta columna contiene fechas, se cambiara su tipo de dato de "object" a "date_time" para mejorar el analisis
#
# - La columna magType, hace referencia al tipo de magnitud registrada, la clasificación de las mismas se puede encontrar en este --> [link](https://www.usgs.gov/programs/earthquake-hazards/magnitude-types) <--, se cambiará su nombre a "tipo_magnitud"
# - La columna net, hace referencia a la "Network" o red sismologica que detecto el evento, si se desea saber más sobre a qué hace referencia cada codigo revisar esta --> [página](http://www.fdsn.org/networks/?search=nc) <--, se cambiará su nombre a "red_sismologica"
# - La columna id, hace referencia a la identificación del evento sucedido, se cambiará su nombre a "identificacion"
# - La columna updated, hace referencia a la fecha y a su respectiva hora en la que se modificó la medida del evento, se cambiará su nombre a "fecha_modificacion". Al igual que la columna fecha, el tipo de dato de esta columna debe cambiarse para ser tomada como una fecha y no un texto
# - La columna place, hace referencia al lugar donde sucedió el evento, se cambiará su nombre a "lugar_evento"
# - La columna type, hace referencia al tipo de evento que se documentó, en este caso tan particular, todos los eventos son del tipo "earthquake", por lo que se puede borrar esta columna sin afectar la integridad del dataframe, primero confirmemos esto antes de eliminarla, se cambiará su nombre a "tipo_evento"
# - La columna status, hace referencia al estado o estado de procesamiento de un evento sísmico. Proporciona información sobre la etapa en la que se encuentra el evento sísmico en el proceso de recopilación, análisis y reporte de datos, recibirá el nombre de "estado_evento"
# - La columna  locationSource, hace referencia a la fuente o el método utilizado para determinar la ubicación de un evento sísmico registrado. Sus valores son similares a los de la columna red_sismologica. Se cambiará su nombre a "fuente_localizacion"
# - La columna magSource, hace referencia a la fuente o la agencia responsable de calcular la magnitud de un evento sísmico. Sus valores son similares a los de la columna red_sismologica y fuente_localizacion. Se cambiará su nombre a "fuente_magnitud"

# %%
# cambio de nombre de las columnas
nuevos_nombres = {'time' : 'fecha',
'magType': 'tipo_magnitud',
'net': 'red_sismologica',
'id': 'identificacion',
'updated': 'fecha_modificacion',
'place':'lugar_evento',
'type':'tipo_evento',
'status':'estado_evento',
'locationSource':'fuente_localizacion',
'magSource':'fuente_magnitud'}
df.rename(columns = nuevos_nombres, inplace=True)

# cambio de tipo de dato de las columnas fecha y fecha_modificacion
df['fecha'] = pd.to_datetime(df['fecha'])
df['fecha_modificacion'] = pd.to_datetime(df['fecha_modificacion'])

# %% [markdown]
# #### Columna fecha

# %% [markdown]
# Teniendo las fechas, podemos comenzar el análisis revisando desde cuando están disponibles los datos:

# %%
df.fecha.head(1)
# Out:
# 0   2023-06-29 04:46:02.350000+00:00
# Name: fecha, dtype: datetime64[ns, UTC]

# %%
df.fecha.tail(1)
# Out:
# 429324   2018-01-01 00:01:50.770000+00:00
# Name: fecha, dtype: datetime64[ns, UTC]

# %% [markdown]
# Tenemos un rango de datos desde el 29 de junio del 2023, hasta el 1 de enero de 2018. 5 años de datos para analizar. Observemos de los datos disponible, que año tiene la mayor cantidad de terremotos:

# %%
conteo = df['fecha'].dt.year.value_counts()
plt.bar(conteo.index, conteo.values)
plt.xlabel('Año')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Año')
plt.show()

# %% [markdown]
# Se puede observar que el año con mayor eventos registrados es el 2020, seguido por el 2019, con esto presente, se puede optar por tomar estos años como referente para la creación del modelo de clasificación de terremotos. Miremos la cantidad de terremotos por meses

# %%
conteo = df['fecha'].dt.month.value_counts()
plt.bar(conteo.index, conteo.values)
nombres_meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
                 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
plt.xticks(conteo.index.sort_values(),labels=nombres_meses,rotation = 75)
plt.xlabel('Mes')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Mes')
plt.show()

# %% [markdown]
# El mes con mayor cantidad de terremotos históricamente fue julio. Con estos dos datos, podemos enfocar el modelado con respecto a la época del año o del año mismo. Ahora, observemos las columnas de tipo string.

# %%
df.describe(include = "O")
# Out:
#        tipo_magnitud red_sismologica identificacion
# count         429324          429325         429325  \
# unique            12              14         429325
# top               ml              ci     nc73906566
# freq          289805          162890              1
#
#                      lugar_evento tipo_evento estado_evento
# count                      428485      429325        429325  \
# unique                      51394           1             2
# top     7km NW of The Geysers, CA  earthquake      reviewed
# freq                         6965      429325        332808
#
#        fuente_localizacion fuente_magnitud
# count               429325          429325
# unique                  16              17
# top                     ci              ci
# freq                162893          162898

# %% [markdown]
# En esta tabla podemos extraer información valiosa para nuestro análisis pues podemos ver si hay datos nulos, el dato de mayor frecuencia, y la cantidad de datos únicos por columna, revisaremos cada columna detenidamente

# %% [markdown]
# #### Columna tipo_magnitud
#
# De esta columna podemos observa que:
#
# - De 429325, tiene 429324, hace falta un dato, el cual corresponde a:

# %%
df[df.tipo_magnitud.isna()]
# Out:
#                                   fecha   latitude  longitude  depth  mag
# 245265 2020-04-11 18:02:20.750000+00:00  38.056833   -118.728   6.44  3.2  \
#
#        tipo_magnitud   nst   gap   dmin   rms  ...
# 245265           NaN  36.0  98.0  0.262  0.05  ...  \
#
#                      fecha_modificacion          lugar_evento tipo_evento
# 245265 2021-02-19 19:20:19.932000+00:00  30km SE of Bodie, CA  earthquake  \
#
#        horizontalError depthError  magError  magNst  estado_evento
# 245265            0.32        2.7       NaN     NaN       reviewed  \
#
#         fuente_localizacion fuente_magnitud
# 245265                   nc              nc
#
# [1 rows x 22 columns]

# %% [markdown]
# Se puede ver como la consulta tiene no solo la columna tipo_magnitud con un valor NAN o nulo, sino también hay otras con estos valores, por lo que se podría considerar un error y se puede considerar su eliminación del dataframe.

# %% [markdown]
# - La columna tiene 12 valores unicos, de los que el valor "ml" es el de mayor frecuencia:

# %%
conteo = df['tipo_magnitud'].value_counts()
sns.barplot(x=conteo.index, y=conteo.values)
# Agregar líneas guías horizontales en las posiciones deseadas
posiciones_guias = [50000, 150000, 250000]  # Lista de posiciones de las líneas guías
for posicion in posiciones_guias:
    plt.axhline(y=posicion, color='gray', linestyle='--')
# Agregar los valores encima de cada barra
for i, v in enumerate(conteo.values):
    plt.text(i, v + 0.5, str(v), ha='center')
# Personalizar los ejes y el título
plt.xlabel('Tipo de Magnitud')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por tipo de magnitud')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# Aparte de del dato 'ml', el siguiente dato con mayor frecuencia es 'md' de resto, la frecuencia de datos es mínima, y muy pequeña a comparación de los dos datos más grandes

# %% [markdown]
# ### Significado Magnitudes
#
# ##### ML:Magnitud de onda local (Local Magnitude).
# También conocida como magnitud de Richter, es una medida de la amplitud de las ondas sísmicas registradas en sismógrafos cercanos al epicentro. Se utiliza principalmente para sismos de menor magnitud y en distancias cortas.
#
# ##### MD: Magnitud de duración (Duration Magnitude).
#  Es una medida de la energía liberada por un terremoto basada en la duración total de las ondas sísmicas registradas. Se utiliza en terremotos de magnitud moderada a grande.
#
# ##### MB-LG: Magnitud de onda corporal y superficie (Body and Surface Wave Magnitude).
# Es una medida de la energía liberada por un terremoto basada en la amplitud de las ondas sísmicas registradas tanto en ondas corporales como en ondas superficiales. Esta magnitud se utiliza para terremotos de magnitud moderada a grande.
#
# ##### MW: Magnitud de momento (Moment Magnitude).
# Es una medida de la energía total liberada por un terremoto, que se calcula a partir del desplazamiento relativo a lo largo de la falla sísmica y el área de la superficie de la falla. Se considera una medida más precisa y confiable para terremotos de magnitud grande.
#
# ##### MH: Magnitud de Hudson (Hudson Magnitude).
# Es una medida de la amplitud de las ondas sísmicas registradas en sismógrafos específicos utilizados por la red sísmica del Observatorio Lamont-Doherty de la Universidad de Columbia.
#
# ##### MLR: Magnitud de onda local revisada (Revised Local Magnitude).
# Es una versión revisada de la magnitud de onda local (ML) que toma en cuenta correcciones y ajustes adicionales en los cálculos.
#
# ##### MWR: Magnitud de momento revisada (Revised Moment Magnitude).
# Es una versión revisada de la magnitud de momento (MW) que incorpora correcciones y ajustes adicionales.
#
# ##### MB: Magnitud de duración revisada (Revised Duration Magnitude).
# Es una versión revisada de la magnitud de duración (MD) que toma en cuenta correcciones y ajustes adicionales.
#
# ##### MWW: Magnitud de momento en banda ancha (Moment Magnitude from Broadband).
# Es una versión de la magnitud de momento (MW) calculada a partir de registros de banda ancha de ondas sísmicas.
#
# ##### MLV: Magnitud de onda local vertical (Vertical Local Magnitude).
# Es una medida de la amplitud de las ondas sísmicas registradas en sismógrafos verticales cercanos al epicentro.
#
# ##### MLG: Magnitud de onda local horizontal (Horizontal Local Magnitude).
# Es una medida de la amplitud de las ondas sísmicas registradas en sismógrafos horizontales cercanos al epicentro.
#
# ##### MUN: Magnitud de onda uniforme (Uniform Magnitude).
# Es una magnitud que se calcula utilizando un método uniforme para todos los terremotos registrados en una red sísmica específica.

# %% [markdown]
# #### columna red_sismologica

# %% [markdown]
# Se puede observar de esta columna:

# %% [markdown]
# - No tiene datos nulos
# - Su dato de mayor frecuencia es 'ci', con una frencuencia de 162890

# %%
conteo = df['red_sismologica'].value_counts()
sns.barplot(x=conteo.index, y=conteo.values)
# Agregar líneas guías horizontales en las posiciones deseadas
posiciones_guias = [40000, 80000, 120000, 160000]  # Lista de posiciones de las líneas guías
for posicion in posiciones_guias:
    plt.axhline(y=posicion, color='gray', linestyle='--')
# Agregar los valores encima de cada barra
for i, v in enumerate(conteo.values):
    plt.text(i, v + 0.5, str(v), ha='center')
# Personalizar los ejes y el título
plt.xlabel('Tipo de Magnitud')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por tipo de magnitud')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Columna identificacion

# %% [markdown]
# Esta columna contiene la identificación de cada terremoto, no tiene nulos, y todos los datos son únicos, por lo que se puede obviar esta columna del análisis, se recomienda eliminar la columna por su nulo uso para la realización del modelo

# %% [markdown]
# #### Columna lugar_evento

# %% [markdown]
# De esta columna podemos observar que:

# %% [markdown]
# - Hay datos nulos en esta columna

# %%
Cantidad_nulos = df[df.lugar_evento.isna()].shape[0]
Cantidad_disponibles = df[~df.lugar_evento.isna()].shape[0]
valores = [Cantidad_nulos,Cantidad_disponibles ]
titulos = ['Datos nulos', 'Datos disponibles']
colores = ['#22A699' ,'#F29727']

plt.pie(valores, labels=titulos, colors=colores, autopct='%1.1f%%')
plt.title('Porcentaje de datos nulos y disponibles en lugar_evento')

plt.show()

# %% [markdown]
# Pero al ser una ínfima cantidad de todos los datos, podríamos pasarlo por alto. No debería perjudicar el usar esta categoría al hacer un modelo

# %% [markdown]
# - Hay una gran cantidad de datos unicos, hagamos una nube de palabras para ver que palabras son las más comunes.

# %%
#dejar solo el pais o lugar en el "lugar evento"
df['lugar_evento'] = df['lugar_evento'].str.extract(r'(?:[^,]*,)*([^,]*)$')

# %%
# Extraer los valores de la columna deseada en forma de texto
texto = ' '.join(df['lugar_evento'].dropna().astype(str).tolist())

# Tokenizar el texto en palabras individuales
tokens = word_tokenize(texto)

# Eliminar las stopwords del texto tokenizado
stop_words = set(stopwords.words(['english']))  # Cambia 'english' al idioma de tu elección
tokens = [word for word in tokens if word.lower() not in stop_words]

# Unir los tokens nuevamente en un solo texto
filtered_text = ' '.join(tokens)

# Crear la nube de palabras
wordcloud = WordCloud().generate(filtered_text)

# Visualizar la nube de palabras
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Se puede observar como las palabras más relevantes son: Nevada ( lo que implica que esta locación suele tener muchos terremotos o al menos en el histórico), CA ( diminutivo de california, otra localidad que aparece mucho en los registros), Utah, Montana, Oklahoma . La columna lugar_evento nos puede ser muy útil para definir la zona de donde se captó el terremoto, pero en cuestiones de ayudarnos en la creación de un modelo que nos ayude a clasificar los terremotos, no sería de gran ayuda. Se recomienda eliminar esta columna.

# %% [markdown]
# #### Columna tipo_evento

# %% [markdown]
# Esta columna se puede obviar completamente en este caso, solo contiene un dato (repetido varias veces) que sería "eartquake" o terremoto en español

# %% [markdown]
# #### Columna estado_evento

# %% [markdown]
# Podemos observar de esta columna:

# %% [markdown]
# - No tiene valores nulos
# - Solo tiene 2 posibles valores: automatic, reviewed; estos hacen referencia a la manera de como fueron registrado los terremotos, veamos su porcentaje en el dataframe:

# %%
cantidad_valores = df.estado_evento.value_counts()
valores = [ cantidad_valores.values[0] ,cantidad_valores.values[1] ]
titulos = [cantidad_valores.index[0], cantidad_valores.index[1]]
colores = ['#22A699' ,'#F29727']

plt.pie(valores, labels=titulos, colors=colores, autopct='%1.1f%%')
plt.title('Porcentaje de datos en estado_evento')

plt.show()

# %% [markdown]
# Se puede ver como la mayoría de datos fueron revisados por encargados ya que hay más datos "reviewed" que "automatic". Esta columna puede ser borrada, si no se necesita filtrar la información por como se obtuvo.

# %% [markdown]
# #### Columnas fuente_localizacion y fuente_magnitud

# %% [markdown]
# Se ha decidido analizar ambas columnas por igual, por la igualdad de datos. De antemano, se debe entender que ambas columnas almacenan el código del centro ( al igual que la columna red_sismologica ), en una vista previa de los datos, se veía que ambas columnas tenían datos repetidos. Observemos las características de ambas columnas:

# %% [markdown]
# - Ambas columnas no tienen datos nulos
# - La diferencia es que fuente_localizacion tiene 16 datos unicos, mientras fuente_magnitud 17. Al haber un dato de más, se puede descartar la idea de que sean iguales.
#
# Estas dos columnas pueden servirnos para filtrar datos, pero al momento de usarla en un modelo, poco podría servirnos por su correlación de datos, se recomienda obviar ambas columnas.

# %%
df.fuente_localizacion.unique()
# Out:
# array(['nc', 'ci', 'ok', 'nn', 'uw', 'uu', 'tx', 'us', 'mb', 'nm', 'se',
#        'ew', 'ld', 'ismp', 'ott', 'tul'], dtype=object)

# %%
df.fuente_magnitud.unique()
# Out:
# array(['nc', 'ci', 'ok', 'nn', 'uw', 'uu', 'tx', 'us', 'mb', 'nm', 'se',
#        'ott', 'slm', 'ew', 'ld', 'ismp', 'tul'], dtype=object)

# %% [markdown]
# El único dato de más, en la columna fuente_magnitud es 'slm'

# %%
conteo = df['fuente_localizacion'].value_counts()
conteo
# Out:
# fuente_localizacion
# ci      162893
# nc      118403
# nn       64547
# uu       24123
# ok       15531
# uw       12234
# mb       12171
# tx        8110
# us        7230
# nm        2257
# se         967
# tul        492
# ismp       257
# ld          86
# ott         23
# ew           1
# Name: count, dtype: int64

# %% [markdown]
# **CI:** Red Sísmica de California (California Integrated Seismic Network)
# **NC:** Red Sísmica de Carolina del Norte (North Carolina Seismic Network)
# **NN:** Red Nacional de Sismología de Canadá (National Seismograph Network)
# **UU:** Red Sísmica de Utah (University of Utah Seismograph Stations)
# **OK:** Red Sísmica de Oklahoma (Oklahoma Geological Survey)
# **UW:** Red Sísmica de Washington (Pacific Northwest Seismic Network)
# **MB:** Red Sísmica de Manitoba, Canadá (Manitoba Seismic Network)
# **TX:** Red Sísmica de Texas (TexNet Seismic Monitoring Program)
# **US:** Red Sísmica de los Estados Unidos (United States Geological Survey)
# **NM:** Red Sísmica de Nuevo México (New Mexico Tech Seismic Network)
# **SE:** Red Sísmica del Sureste de los Estados Unidos (Southeast U.S. Seismic Network)
# **TUL:** Red Sísmica de la Universidad de Tulsa (University of Tulsa Seismic Network)
# **ISMP:** Red Sísmica Internacional (International Seismological Centre)
# **LD:** Red Sísmica de Londres (London Seismic Network)
# **OTT:** Red Sísmica de Ottawa (Ottawa-Gatineau Seismic Monitoring Centre)
# **EW:** Red Sísmica del Oeste de los Estados Unidos (Earthquake Hazards Program Western Region)

# %% [markdown]
# ### Columnas tipo númerico

# %% [markdown]
# Esta son las columnas con datos numéricos decimales, al igual que en el análisis de las columnas tipo texto, antes de comenzar es bueno entender a qué hace referencia cada columna y darles un nombre más intuitivo. Observemos de forma general el contenido del dataframe en busca de darle un mejor nombre a las columnas por su contenido.

# %%
df.select_dtypes(include=['float']).head()
# Out:
#     latitude   longitude      depth   mag   nst         gap      dmin
# 0  38.796166 -122.781166   3.830000  0.28   6.0  145.000000  0.006061  \
# 1  33.659167 -116.732167  12.400000  0.39  17.0   54.000000  0.053990
# 2  38.824165 -122.804001   2.470000  0.20   8.0   81.000000  0.017540
# 3  34.048667 -117.166333  10.610000  1.34  47.0   60.000000  0.046670
# 4  35.881329  -98.047607   7.989354  1.77  10.0   86.452896  0.087374
#
#         rms  horizontalError  depthError  magError  magNst
# 0  0.010000         1.120000    3.040000     0.040     8.0
# 1  0.110000         0.240000    0.380000     0.133    11.0
# 2  0.030000         0.480000    1.390000     0.080     8.0
# 3  0.180000         0.230000    0.420000     0.234    25.0
# 4  0.488169         4.835118    6.372441     0.290     4.0

# %% [markdown]
# - La columna latitude y longitude, almacenan las coordenadas geograficas donde se registró el terremoto. Si necesitas saber más de latitud y longitud de las coordenadas geograficas, presiona -->[Aqui](https://es.wikipedia.org/wiki/Coordenadas_geogr%C3%A1ficas)<--. Por facilidad linguistica, se cambiara el nombre a las columnas por: "latitud" y "longitud"
# - La columna depth, se refiere a la profundidad del evento sísmico registrado. Su valor expresa la distancia en kilometros, se cambiará su nombre a "profundidad"
# - La columna mag, se refiere a la magnitud del evento sísmico registrado. La magnitud es una medida numérica que representa la energía liberada por un evento sísmico y se utiliza para describir su tamaño o intensidad. Si se desea saber más sobre la magnitud de un evento sismico, haz click --> [aquí](https://es.wikipedia.org/wiki/Escala_sismol%C3%B3gica_de_Richter) <--. Se cambiará su nombre a "magnitud"
# - La columna nst se refiere al número de estaciones que contribuyeron a la determinación de la magnitud de un evento sísmico. "nst" significa "number of stations" en inglés, que se traduce como "número de estaciones" en español. Se cambiará su nombre a "numero_estaciones"
# - La columna gap, se refiere al ángulo de brecha (gap angle, en inglés) en el contexto de la ubicación de las estaciones sísmicas. El ángulo de brecha se utiliza para medir la cobertura angular de las estaciones sísmicas en relación con un evento sísmico específico.Un valor de gap cercano a cero indica una buena cobertura angular, lo que significa que las estaciones sísmicas están bien distribuidas alrededor del evento y proporcionan una visión completa de la actividad sísmica en esa área. Por otro lado, un valor de gap cercano a 180 o más indica una cobertura deficiente, lo que significa que hay una brecha significativa en la cobertura de las estaciones alrededor del evento. Se cambiará su nombre por "angulo_brecha"
# - La columna dmin, se refiere a la distancia mínima (en inglés, "minimum distance") entre una estación sísmica y el epicentro de un evento sísmico registrado. El valor numérico en la columna "dmin" indica la distancia más corta en kilómetros entre una estación sísmica específica y la ubicación estimada del epicentro del evento. Se cambiará su nombre por "distancia_minima"
# - La columna rms, se refiere al error cuadrático medio (Root Mean Square, RMS en inglés) de las lecturas sísmicas. El valor numérico en la columna "rms" representa la medida del error promedio entre las lecturas observadas y las lecturas esperadas de las estaciones sísmicas involucradas en la detección y registro del evento sísmico. Su nombre se cambiará por "error_cuadrático"
# - La columa horizontalError, se refiere al error horizontal estimado asociado con la ubicación del epicentro de un evento sísmico registrado. Indica la incertidumbre en la determinación de la ubicación horizontal del evento sísmico. Su nombre se cambiará "error_horizontal"
# - La columna depthError, se refiere al error estimado asociado con la profundidad del evento sísmico registrado. Indica la incertidumbre en la determinación de la ubicación vertical del evento. Su nombre se cambiará "error_profundidad"
# - La columna magError, se refiere al error estimado asociado con la magnitud del evento sísmico registrado. Indica la incertidumbre en la determinación de la magnitud del evento. Su nombre se cambiará por "error_magnitud"
# - La columna magNst, se refiere al número de estaciones que contribuyeron al cálculo de la magnitud de un evento sísmico. "magNst" es una abreviatura de "Magnitude Station Count" en inglés, que se traduce como "Cantidad de Estaciones de Magnitud" en español. Su nombre se cambiará por "cantidad_estaciones_magnitud"

# %% [markdown]
# Bajo la idea de buscar valores que nos ayuden a realizar un modelo de clasificación y considerando el contexto de las columnas, consideramos que las columnas de errores de medición no será necesario analizarlas pues nos dan valores descriptivos de los eventos que podemos usar directamente en la creación del modelo.

# %%
nuevos_nombres = {
    'latitude': 'latitud',
    'longitude': 'longitud',
    'depth': 'profundidad',
    'mag':'magnitud',
    'nst':'numero_estaciones',
    'gap':'angulo_brecha',
    'dmin':'distancia_minima',
    'rms':'error_cuadrático',
    'horizontalError':'error_horizontel',
    'depthError':'error_profundidad',
    'magError':'error_magnitud',
    'magNst':'cantidad_estaciones_magnitud'
}
df.rename(columns = nuevos_nombres, inplace=True)

# %% [markdown]
# Con los nuevos nombres listos, podemos comenzar con el análisis de las variables cuantitativas. Observemos una descripción general de los datos en conjunto a una matriz de correlación

# %%
df.describe()
# Out:
#              latitud       longitud    profundidad       magnitud
# count  429325.000000  429325.000000  429325.000000  429325.000000  \
# mean       37.374776    -116.830801       6.289726       1.144406
# std         3.373114       6.325400       4.743194       0.664789
# min        24.751800    -124.999333      -3.500000       0.000000
# 25%        35.619335    -119.935900       2.610000       0.670000
# 50%        37.299900    -117.707667       5.640000       1.040000
# 75%        38.812168    -116.504333       8.820000       1.510000
# max        49.969900     -65.068200      93.410000       7.100000
#
#        numero_estaciones  angulo_brecha  distancia_minima  error_cuadrático
# count      423185.000000  429289.000000     425008.000000     429232.000000  \
# mean           20.555043     102.352495          0.081391          0.133898
# std            15.660134      54.041104          0.124035          0.128496
# min             0.000000       7.000000          0.000000          0.000000
# 25%            10.000000      64.000000          0.020340          0.060000
# 50%            16.000000      89.000000          0.048260          0.127300
# 75%            25.000000     128.000000          0.089960          0.180000
# max           289.000000     360.000000          6.219000         46.240000
#
#        error_horizontel  error_profundidad  error_magnitud
# count     349461.000000      429233.000000   392201.000000  \
# mean           0.464605           1.863667        0.188239
# std            0.621727          11.414633        0.128042
# min            0.060000           0.000000        0.000000
# 25%            0.220000           0.440000        0.115000
# 50%            0.310000           0.680000        0.164000
# 75%            0.490000           1.210000        0.228000
# max           99.000000        4247.400000        2.820000
#
#        cantidad_estaciones_magnitud
# count                 410596.000000
# mean                      12.700509
# std                       15.706565
# min                        0.000000
# 25%                        4.000000
# 50%                        9.000000
# 75%                       16.000000
# max                      345.000000

# %%
# Visualizar la matriz de correlación
columnas_seleccionadas = df.select_dtypes(include=['float']).columns.tolist()
columnas_data = df[columnas_seleccionadas]

# Calcular la matriz de correlación
correlation_matrix = columnas_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Gracias a la matriz de la correlación, se puede ver que la mayoría de variables (columnas) son independientes entre ellas, habiendo solo algunas de ellas con un mínimo de correlación que revisaremos dependiendo del caso

# %% [markdown]
# #### Columna latitud y longitud

# %% [markdown]
# Ambas columnas son numéricas como se había descrito anteriormente, pero estas no deben ser procesadas como meros números. Cada columna trata de una dirección un acontecimiento, operar estos valores no nos traerá nada significativo, no obstante, se pueden sacar algunas conclusiones de los percentiles:

# %% [markdown]
# - En general, son valores cercanos entre ellos y a los valores mínimos y máximos, numéricamente implica una distribución normal sin outliers o datos atípicos, pero en el contexto de las variables, implica que las localizaciones a las que hace referencia son "cercanas" entre ellas. Algo muy obvio si se considera que el dataframe trata de terremotos de Estados Unidos.

# %% [markdown]
# Se recomienda utilizar estos valores para filtrar los datos del modelo.

# %% [markdown]
# #### Columna profundidad

# %% [markdown]
# Podemos observa de esta columna que:

# %% [markdown]
# - No hay datos nulos

# %% [markdown]
# - El valor mínimo es -3.5, lo que podría considerarse un outlier o error pues las profundidades deberían ser valores negativos, observemos si hay más datos como este:

# %%
df[df.profundidad< 0 ].shape[0]
# Out:
# 9907

# %% [markdown]
# Hay 9907 datos, donde la profundidad es menor a 0. Según la USGS (Servicio Geológico de los Estados Unidos) no es común que se reporten profundidades negativas en el contexto de los eventos sísmicos. La profundidad generalmente se mide en relación con la superficie de la Tierra, y una profundidad negativa indicaría que el evento sísmico ocurrió por debajo de la superficie del suelo o el nivel del mar. Sin embargo, es importante tener en cuenta que en algunos casos particulares o en ciertos contextos geológicos específicos, como en regiones con cuencas sedimentarias o zonas de hundimiento, es posible encontrar informes de eventos sísmicos con profundidades negativas. Esto puede ocurrir cuando los movimientos tectónicos o los procesos geológicos han causado un hundimiento de la corteza terrestre en relación con un punto de referencia de referencia. De manera que se pueden descartar estos datos como errores y ser tomados como datos atípicos. Observemos la distribución de estos datos con un histograma y un diagrama de velas.

# %%
plt.boxplot(df.profundidad, vert=False)

# Configuración adicional
plt.xlabel('Valor')
plt.title('Diagrama de Caja')
# Out:
# Text(0.5, 1.0, 'Diagrama de Caja')

# %% [markdown]
# Podemos ver varios puntos negros hacia la derecha, estos muestran todos los valores que están más allá del percentil del 75%, valores muy altos para la distribución de los datos. Esto es signo de una gran variedad de datos numéricos, por consiguiente varias formas de agrupación posible.

# %% [markdown]
# #### Columna magnitud

# %% [markdown]
# Podemos observar de esta columna:

# %% [markdown]
# - No hay datos nulos

# %% [markdown]
# - El valor mínimo es 0, y el máximo 7.1

# %%
#Sismos por Magnitud
#Copia y redondeo de magnitud

df_copia = df.copy()
df_copia['magnitud'] = df_copia['magnitud'].round()
df_copia = df_copia[df_copia['magnitud'] > 0]

sns.catplot(
    data=df_copia,
    x='magnitud',
    kind='count',
)
plt.title('Cantidad de Sismos por Magnitud')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Podemos observar que los sismos más comunes son entre 1 a 3 de magnitud, mientras los sismos de mayor magnitud ( en el periodo de tiempo registrado) son relativamente pocos

# %% [markdown]
# #### Columna numero_estaciones

# %% [markdown]
# Podemos observar de esta columnas:

# %% [markdown]
# - Hay valores faltantes

# %% [markdown]
# - El valor minino es 0, y el máximo 289

# %%
df_copia = df.copy()
df_copia['magnitud'] = df_copia['magnitud'].round()
df_copia = df_copia[df_copia['magnitud'] > 0]

sns.catplot(x="magnitud", y="numero_estaciones", data=df_copia)

# Configurar los ejes y el título
plt.xlabel("Magnitud del sismo")
plt.ylabel("Cantidad de estaciones")
plt.title("Cantidad de estaciones por magnitud de sismo")

# Mostrar el catplot
plt.show()

# %% [markdown]
# Se puede ver cierta tendencia a la alza con respecto a la cantidad de estaciones y la magnitud del sismo, algo que se podía ver en la matriz de correlación y ya que, la correlación de esta columna, con respecto a numero_estaciones_magnitud es tan alta, el resultado puede ser el mismo, por lo que se obviara el análisis de la segunda columna.

# %% [markdown]
# #### Columna angulo_brecha

# %% [markdown]
# De esta columna podemos observar:

# %% [markdown]
# - Hay datos faltantes

# %% [markdown]
# - El mínimo valor es 7 y el máximo 360

# %% [markdown]
# Observemos un histograma de la cantidad de valores con respecto a su angulo de brecha

# %%
# Crear el histograma
plt.hist(df['angulo_brecha'], bins='auto')

# Configurar los ejes y el título
plt.xlabel('Valor')
plt.ylabel('Cantidad de datos')
plt.title('Histograma de la columna angulo_brecha')

# Mostrar el histograma
plt.show()

# %% [markdown]
# Bajo el contexto de la descripción dada para la columna, los valores cercanos a 180 implican que son mediciones engañosas y con fallos, por suerte no son demasiados datos, pero hay que tenerlos presentes. Teniendo esto presente, habría que tener presente esto al momento de hacer el modelo de clasificación

# %%
#Cantidad de datos cercanos 
df[((df.angulo_brecha<= 210 ) & (df.angulo_brecha>= 150 ))].angulo_brecha.count()
# Out:
# 49492

# %%
df[df.angulo_brecha== 180].angulo_brecha.count()
# Out:
# 504

# %% [markdown]
# En un rango de +-30 grados, tenemos 49492 registros cercanos a 180, y 504 datos que su angulo de brecha es de 180.

# %% [markdown]
# #### Columna distancia_minima

# %% [markdown]
# Podemos observar de esta columna que:

# %% [markdown]
# - Hay datos nulos

# %%
faltantes = df.shape[0] - df.distancia_minima.count()
faltantes
# Out:
# 4317

# %% [markdown]
# - los percentiles son muy bajos con respecto al valor máximo,  que es de 6.219, revisemos este comportamiento con una histograma

# %%
# Crear el histograma
plt.hist(df['distancia_minima'], bins='auto')

# Configurar los ejes y el título
plt.xlabel('Valor')
plt.ylabel('Cantidad de datos')
plt.title('Histograma de la columna distancia_minima')

# Mostrar el histograma
plt.show()

# %% [markdown]
# Parece haber ciertos outliers, observemos el mismo gráfico pero está vez en un grafico de vela

# %%
# Crear el boxplot
sns.boxplot(data=df.distancia_minima)

# Configurar el título
plt.title('Diagrema de caja')

# Mostrar el boxplot
plt.show()

# %% [markdown]
# Se ven varios datos por encima de la linea del percentil del 75%, miremos la cantidad de datos que están por encima de este percentil:

# %%
atipicos = df[df.distancia_minima >0.08996].distancia_minima.count()
atipicos
# Out:
# 106249

# %%
valores = [ df.distancia_minima.count()-atipicos ,atipicos ]
titulos = ["Valores en el rango de los percentiles", "Valores atipicos"]
colores = ['#22A699' ,'#F29727']

plt.pie(valores, labels=titulos, colors=colores, autopct='%1.1f%%')
plt.title('Porcentaje de datos en distancia_minima')

plt.show()

# %% [markdown]
# Hay una gran cantidad de valores atipicos, hay que tener eso presente, pues los valores atipicos implican que la distancia entre el sismo y la fuente de información son muy lejanas, generando errores de medición.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# -

# %% [markdown]
# ## JAPON

# %% [markdown]
# La idea detrás de analizar las fuentes de datos faltantes, es buscar información similar entre las fuentes para que al ingestarlas en la base de datos no halla problemas de normalización

# %% [markdown]
# ### Creación del dataframe a analizar:

# %%
df = pd.read_csv('../../src/data/japan_df.csv')

# %% [markdown]
# ### Comienzo del análisis:

# %% [markdown]
# Observemos de forma general la estructura del dataframe, la cantidad de filas, columnas, nombres y ya luego de ello, qué columnas podemos usar en conjunto al de USA

# %%
df.shape
# Out:
# (172, 14)

# %% [markdown]
# Tenemos 172 filas y 14 columnas, menos que en el conjunto de datos de USA. El nombre de las columnas son:

# %%
df.columns
# Out:
# Index(['det_fecha_hora', 'epi', 'mag', 'int_max', 'emis_fecha_hora', 'href',
#        'det_fecha_hora_local', 'lat_0', 'lon_0', 'prof_epi', 'id',
#        'prof_epi_nro', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# Al igual que en el análisis de USA, posteriormente cambiaremos el nombre de la columna dependiendo de su contexto, se buscará que los nombres sean iguales a su símil del conjunto de datos de USA. Los nombres que tienen las columnas son:

# %% [markdown]
# - det_fecha_hora

# %% [markdown]
# - epi

# %% [markdown]
# - mag

# %% [markdown]
# - int_max

# %% [markdown]
# - emis_fecha_hora

# %% [markdown]
# - href

# %% [markdown]
# - det_fecha_hora_local

# %% [markdown]
# - lat_0

# %% [markdown]
# - lon_0

# %% [markdown]
# - prof_epi

# %% [markdown]
# - id

# %% [markdown]
# - prof_epi_nro

# %% [markdown]
# - lat

# %% [markdown]
# - lon

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   det_fecha_hora        172 non-null    object
#  1   epi                   172 non-null    object
#  2   mag                   172 non-null    float64
#  3   int_max               172 non-null    object
#  4   emis_fecha_hora       172 non-null    object
#  5   href                  172 non-null    object
#  6   det_fecha_hora_local  172 non-null    object
#  7   lat_0                 172 non-null    object
#  8   lon_0                 172 non-null    object
#  9   prof_epi              172 non-null    object
#  10  id                    172 non-null    int64
#  11  prof_epi_nro          172 non-null    float64
#  12  lat                   172 non-null    float64
#  13  lon                   172 non-null    float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# Las columnas del dataframe tienen distintos tipos de datos, por lo que se pueden categorizar las columnas por el tipo de datos que contengan.

# %% [markdown]
# Las columnas de tipo texto son:

# %% [markdown]
# - det_fecha_hora
# - epi
# - int_max
# - emis_fecha_hora
# - href
# - det_fecha_hora_local
# - lat_0
# - lon_0
# - prof_epi

# %% [markdown]
# Las columnas tipo numérico ( en esta oportunidad tenemos del tipo float (decimal) e int ( entero)) son:

# %% [markdown]
# - mag
# - id
# - prof_epi_nro
# - lat
# - lon

# %% [markdown]
# Ya con las coluimnas segmentadas, se analizará primero las columnas tipo texto y luego las numéricas

# %% [markdown]
# ### Columnas de tipo texto:

# %% [markdown]
# Comencemos con entender el contenido de las columnas y su contexto:

# %%
df.select_dtypes(include=['object']).head()
# Out:
#         det_fecha_hora                                   epi int_max
# 0  2023-06-28 14:27:00            Sur de Prefectura de Kioto       1  \
# 1  2023-06-28 05:22:00                  Norte de región Soya       2
# 2  2023-06-28 03:02:00        Norte de Prefectura de Ibaraki       1
# 3  2023-06-28 02:25:00                 Este de región Hidaka       2
# 4  2023-06-28 01:27:00  Alta mar este de Prefectura de Chiba       1
#
#        emis_fecha_hora                                               href
# 0  2023-06-28 14:31:00  https://www.data.jma.go.jp/multi/quake/quake_d...  \
# 1  2023-06-28 05:25:00  https://www.data.jma.go.jp/multi/quake/quake_d...
# 2  2023-06-28 03:04:00  https://www.data.jma.go.jp/multi/quake/quake_d...
# 3  2023-06-28 02:28:00  https://www.data.jma.go.jp/multi/quake/quake_d...
# 4  2023-06-28 01:30:00  https://www.data.jma.go.jp/multi/quake/quake_d...
#
#   det_fecha_hora_local  lat_0   lon_0       prof_epi
# 0  2023-06-29 02:27:00  35.0N  135.6E  Poco profundo
# 1  2023-06-28 17:22:00  44.9N  142.1E           10km
# 2  2023-06-28 15:02:00  36.4N  140.6E           60km
# 3  2023-06-28 14:25:00  42.3N  142.8E           30km
# 4  2023-06-28 13:27:00  35.7N  141.4E           10km

# %% [markdown]
# - La columna det_fecha_hora, hace referencia a la fecha y hora a la que se tomó la medida del evento, se cambiará su nombre a "fecha". Como esta columna contiene fechas, se cambiará su tipo de dato de "object" (texto) a "date_time" (tipo de dato para las fechas) para mejorar el analisis.
# - La columna epi, hace referencia al epicentro del evento sismico, definido por la posición relativa de la región de japón en la que se tomó la medida, se cambiará su nombre a "epicentro"
# - La columna int_max, hace referencia a
# - La columna emis_fecha_hora, hace referencia a la fecha y hora en la que se emitió/actualizó la medida del evento, se cambiará su nombre a "fecha_modificacion"
# - La columna href, hace referencia al hipervinculo de la página donde se encuentran más detalles del evento sismico, estos link mandarán al origen de la fuente de datos, se cambiará su nombre a "link_pagina"
# - La columna det_fecha_hora_local, hace referencia a la fecha y hora que se tomó la medida del evento sismico, transformada al horario del lector de la información, como los datos se tomarón desde la ubicación de Argentina, la fecha y hora visualizada es la de Argentina al momento del evento. se cambiará su nombre a "fecha_local"
# - Las columnas lat_0 y lon_0, hacen referencia a la latitud y longitud del evento sismico, con la diferencia con respecto al conjunto de datos de USA que, esta coordenadas suministran el punto cardinal donde se toma la coordenada (N: norte, S: Sur, E: Este, W: Oeste). Esta columna se encuentra relacionada con la columna epicentro, se cambiará sus nombres a "latitud" y "longitud" respectivamente.
# - La columna prof_epi, hace referencia a la profundidad del evento sismico, se cambiará el nombre a "profundidad", como la mayoría de datos parecen ser numeros, se limpiará la información, para tratarla como una columna numérica
#
# Hay varias columnas similires a las vistas en el conjunto de datos de USA, pero con pequeñas diferencias, por esto, se recomienda hacer una transformación de datos para que estas sean lo más similares posible.
#
# De antemano, hay columnas que pueden descartarse por su información tan poco relevante para la generación de un modelo de clasificación, como lo puede ser fecha_modificacion,fecha_local, link_pagina. Por lo que se evitará su analisis

# %%
# cambio de nombre de las columnas
nuevos_nombres = {
 "det_fecha_hora": "fecha",
 "epi": "epicentro",
 "int_max" :"int_max",
 "emis_fecha_hora":"fecha_modificacion",
 "href":"link_pagina",
 "det_fecha_hora_local":"fecha_local",
 "lat_0": "latitud",
 "lon_0": "longitud",
 "prof_epi":"profundidad"
}
df.rename(columns = nuevos_nombres, inplace=True)
# cambio de tipo de dato de las columnas fecha y fecha_modificacion
df['fecha'] = pd.to_datetime(df['fecha'])
df['fecha_modificacion'] = pd.to_datetime(df['fecha_modificacion'])
df['fecha_local'] = pd.to_datetime(df['fecha_local'])

# %% [markdown]
# #### Columna fecha

# %% [markdown]
# Teniendo las fechas, podemos comenzar el análisis revisando desde cuando están disponibles los datos:

# %%
df.fecha.head(1)
# Out:
# 0   2023-06-28 14:27:00
# Name: fecha, dtype: datetime64[ns]

# %%
df.fecha.tail(1)
# Out:
# 171   2023-05-30 01:28:00
# Name: fecha, dtype: datetime64[ns]

# %% [markdown]
# Tenemos un rango de datos desde el 28 de junio del 2023, hasta el 30 de mayo de 2023. Observemos de los datos disponibles, que mes tiene la mayor cantidad de terremotos:

# %%
conteo = df['fecha'].dt.month.value_counts()
plt.bar(conteo.index, conteo.values)
nombres_meses = ['Mayo', 'Junio']
plt.xticks(conteo.index.sort_values(), labels=nombres_meses,rotation = 75)
plt.xlabel('Mes')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Mes')
plt.show()

# %% [markdown]
# El mes con mayor cantidad de terremotos fue junio.

# %% [markdown]
# Revisemos las demás columnas

# %%
df.describe(include = "O")
# Out:
#                              epicentro int_max
# count                              172     172  \
# unique                              55       6
# top     Mares cercanos de Islas Tokara       1
# freq                                38     106
#
#                                               link_pagina latitud longitud
# count                                                 172     172      172  \
# unique                                                172      70       64
# top     https://www.data.jma.go.jp/multi/quake/quake_d...   29.9N   130.0E
# freq                                                    1      23       26
#
#        profundidad
# count          172
# unique          18
# top           10km
# freq            98

# %% [markdown]
# #### Columna epicentro

# %% [markdown]
# Podemos observar de esta columna que:
#
# - No tiene datos faltantes
# - Tiene 55 datos unicos
# - El dato de mayor frecuencia es "Mares cercanos de Islas Tokara" con una frecuencia de 38, revisemos la demás frecuencias que se repiten más de una vez

# %%
conteo = df['epicentro'].value_counts()
conteo = conteo[conteo > 1]
sns.barplot(x=conteo.index, y=conteo.values)
# Agregar líneas guías horizontales en las posiciones deseadas
"""posiciones_guias = [50000, 150000, 250000]  # Lista de posiciones de las líneas guías
for posicion in posiciones_guias:
    plt.axhline(y=posicion, color='gray', linestyle='--')"""
# Agregar los valores encima de cada barra
plt.xticks(rotation=90)
for i, v in enumerate(conteo.values):
    plt.text(i, v + 0.5, str(v), ha='center')
# Personalizar los ejes y el título

plt.xlabel('Región del epicentro')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por región del epicentro')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# Del periodo de tiempo disponible, podemos observar como la mayoría de eventos están relacionados con islas del mar o costas. Dato que podemos usar para el modelo

# %% [markdown]
# #### Columna int_max

# %% [markdown]
# No sé que esta columna... Espacio vacío hasta que sepa qué hacer con ella

# %% [markdown]
# #### Columnas latitud y longitud

# %% [markdown]
# Podemos observar de esta columna que:
#
#
# - No tiene datos nulos
# - La columna latitud tiene 70 datos unicos y la columna longitud 64.
# - El dato más repetido de latitud es 29.9N y en longitud 130.0E

# %%
conteo = df['latitud'].value_counts()
conteo = conteo[conteo > 1]
sns.barplot(x=conteo.index, y=conteo.values)
# Agregar líneas guías horizontales en las posiciones deseadas
"""posiciones_guias = [50000, 150000, 250000]  # Lista de posiciones de las líneas guías
for posicion in posiciones_guias:
    plt.axhline(y=posicion, color='gray', linestyle='--')"""
# Agregar los valores encima de cada barra
plt.xticks(rotation=90)
for i, v in enumerate(conteo.values):
    plt.text(i, v + 0.5, str(v), ha='center')
# Personalizar los ejes y el título

plt.xlabel('Valor de la latitud')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por valor de la latitud')
# Mostrar el gráfico
plt.show()

# %%
conteo = df['longitud'].value_counts()
conteo = conteo[conteo > 1]
sns.barplot(x=conteo.index, y=conteo.values)
# Agregar líneas guías horizontales en las posiciones deseadas
"""posiciones_guias = [50000, 150000, 250000]  # Lista de posiciones de las líneas guías
for posicion in posiciones_guias:
    plt.axhline(y=posicion, color='gray', linestyle='--')"""
# Agregar los valores encima de cada barra
plt.xticks(rotation=90)
for i, v in enumerate(conteo.values):
    plt.text(i, v + 0.5, str(v), ha='center')
# Personalizar los ejes y el título

plt.xlabel('Valor de la longitud')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por valor de la longitud')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Columna profundidad

# %% [markdown]
# Podemos observar de esta columna que:
#
# - No hay nulos
# - la mayoría de datos son numericos, revisemos si podemos limpiarlos

# %%
df.profundidad.unique()
# Out:
# array(['Poco profundo', '10km', '60km', '30km', '480km', '50km', '100km',
#        '40km', '330km', '120km', '160km', '70km', '450km', '20km',
#        '210km', '140km', '80km', '190km'], dtype=object)

# %% [markdown]
# Podemos ver que hay una frase en la lista de valores unicos de la columna profundidad, por esta columna, no podemos tratar todos los datos como numéricos. Revisemos la frecuencia de los datos

# %%
conteo = df['profundidad'].value_counts()
plt.bar(conteo.index, conteo.values)
plt.xticks(conteo.index.sort_values(), rotation = 90)
plt.xlabel('Mes')
plt.ylabel('Cantidad de Registros')
plt.title('Cantidad de Registros por Mes')
plt.show()

# %% [markdown]
# La mayoría de eventos sismicos medidos, pasan entre 0 a 10 km de profundidad.

# %% [markdown]
# ### Columnas de tipo numerico:

# %% [markdown]
# Comencemos con entender el contenido de las columnas y su contexto:

# %%
df.select_dtypes(include=['float', 'int']).head()
# Out:
#    mag              id  prof_epi_nro   lat    lon
# 0  2.2  20230629023106           1.0  35.0  135.6
# 1  3.0  20230628172546          10.0  44.9  142.1
# 2  3.1  20230628150453          60.0  36.4  140.6
# 3  3.4  20230628142811          30.0  42.3  142.8
# 4  4.3  20230628133032          10.0  35.7  141.4

# %% [markdown]
# - La columna mag, hace referencia a la magnitud del evento sísmico, se cambiará su nombre a "magnitud"
# - La columna id, hace referencia a la identificación del evento sismico, no se realizará un analisis de esta columna por ser valores unicos por fila. Se cambiará su nombre a "identificación"
# - La columna prof_epi_nro, hace referencia a la profundidad medida del epicentro, se cambiará su nombre a "profundidad_epicentro"
# - Las columnas lat y lon, hacen referencia al valor numérico de las columnas ya analizadas "latitud" y "longitud", con la unica diferencia que se le dío el valor de 1 a los datos "poca profundidad", estas columnas pasarán a llamarse "valor_latitud" y "valor_longitud" respectivamente

# %%
# cambio de nombre de las columnas
nuevos_nombres = {
 "mag": "magnitud",
 "id": "identificacion",
 "prof_epi_nro" :"profundida_epicentro",
 "lat":"valor_latitud",
 "lon":"valor_longitud"
}
df.rename(columns = nuevos_nombres, inplace=True)

# %% [markdown]
# Observemos estadisticas generales de los datos:

# %%
df.select_dtypes(include=['float','int']).describe()
# Out:
#          magnitud  identificacion  profundida_epicentro  valor_latitud
# count  172.000000    1.720000e+02            172.000000     172.000000  \
# mean     3.295930    2.023061e+13             33.709302      34.811047
# std      0.965326    2.463392e+07             61.209136       6.156511
# min      1.800000    2.023053e+13              1.000000     -22.900000
# 25%      2.500000    2.023060e+13             10.000000      30.000000
# 50%      3.100000    2.023061e+13             10.000000      35.750000
# 75%      3.800000    2.023062e+13             40.000000      37.500000
# max      7.000000    2.023063e+13            480.000000      47.200000
#
#        valor_longitud
# count      172.000000
# mean       136.815116
# std          5.759924
# min        122.500000
# 25%        130.300000
# 50%        137.400000
# 75%        140.725000
# max        176.600000

# %% [markdown]
# Observemos una matriz de correlación de las columnas

# %%
# Visualizar la matriz de correlación
columnas_seleccionadas = df.select_dtypes(include=['float', 'int']).columns.tolist()
columnas_data = df[columnas_seleccionadas]

# Calcular la matriz de correlación
correlation_matrix = columnas_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# Gracias a la matriz de correlacion, se puede ver que la mayoría de variables (columnas) son independientes entre ellas, siendo la única con cierta correlación, la columna profundidad_epicentro con la columna magnitud, esta correlación se puede decartar observando la matriz de correlación del dataframe de USA, pues este teniendo muchos más datos, se podía observar que las columnas profundidad( el simil a la columna profundidad_epicentro) y la columna magnitud, no estaban correlacionadas, por lo que esta correlación se puede tomar como una mera casualidad, se recomienda rehacer el analisis teniendo muchos más datos.

# %% [markdown]
# #### Columna magnitud
#
# Podemos observar de esta columna que:
#
# - No hay datos nulos
# - El promedio es de 3.295930, este está dentro de los percentiles, lo cual implica una distribución normal
# - El valor minimo es 1.8 y el maximo es 7, observemos un histograma para ver la dstribución de los datos

# %%
# Crear el histograma
plt.hist(df['magnitud'], bins='auto')

# Configurar los ejes y el título
plt.xlabel('Valor')
plt.ylabel('Cantidad de datos')
plt.title('Histograma de la columna magnitud')

# Mostrar el histograma
plt.show()

# %%
# Crear el boxplot
sns.boxplot(data=df.magnitud)

# Configurar el título
plt.title('Diagrema de caja')

# Mostrar el boxplot
plt.show()

# %% [markdown]
# Lo que estamos viendo es que no encontramos demasiados outliers o datos atipicos en esta columna.

# %% [markdown]
# #### Columna profundidad_epicentro
#
# Podemos observar de esta columna:
#
# - No hay datos nulos
# - El promedio es de 33.709302, que esta dentro de los percentiles, pero muy cercano al percentil 75%, lo cual puede implicar que haya datos atipicos presentes.
# - Podemos reforzar la teoría anterior, observando que el valor mínimo es 1 pero el máximo es 480. Miremos un diagrama de caja para ver el comportamiento de los datos.

# %%
# Crear el boxplot
sns.boxplot(data=df.profundida_epicentro)

# Configurar el título
plt.title('Diagrema de caja')

# Mostrar el boxplot
plt.show()

# %% [markdown]
# Estos datos no necesariamente deben ser un problema si los emparejamos con los datos de USA, pero si los usamos solos al hacer el modelo, esto podría generar una segmentación de datos no muy eficaz. Se recomienda aplicar más datos al dataframe

# %% [markdown]
# #### Columnas valor_latitud y valor_longitud

# %% [markdown]
# Ambas columnas son numéricas como se había descrito anteriormente, pero estas no deben ser procesadas como meros números. Cada columna trata de una dirección un acontecimiento, operar estos valores no nos traerá nada significativo, no obstante, se pueden sacar algunas conclusiones de los percentiles:

# %% [markdown]
# - En general, son valores cercanos entre ellos y a los valores mínimos y máximos, numéricamente implica una distribución normal sin outliers o datos atípicos, pero en el contexto de las variables, implica que las localizaciones a las que hace referencia son "cercanas" entre ellas.

# %% [markdown]
# # Concluciones

# %% [markdown]
# - Las fuentes de datos analizadas muestran similitudes significativas en varias columnas, lo cual es prometedor para la creación de modelos. Las columnas que presentan similitudes son la magnitud, la latitud y longitud, la profundidad y el lugar del evento. Estas características comunes nos brindan la oportunidad de unificar los datos y utilizarlos en un modelo de manera conjunta.
#
# - Se observó que las columnas de latitud y longitud están en diferentes tipos de coordenadas. Para garantizar la consistencia, se recomienda normalizar estas columnas a un único formato de coordenadas. Esto asegurará que los cálculos y comparaciones basados en estas variables sean precisos y coherentes.
#
# - Aunque no se identificó la necesidad de eliminar las demás columnas del conjunto de datos, es importante tener en cuenta que almacenar todas estas columnas en la misma base de datos puede presentar desafíos. La presencia de columnas adicionales puede aumentar el tamaño de la base de datos y afectar el rendimiento en términos de consultas y procesamiento de datos. Se recomienda evaluar cuidadosamente la viabilidad y relevancia de estas columnas adicionales antes de incluirlas en la base de datos final.
